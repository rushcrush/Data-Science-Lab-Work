# %% [markdown]
# # **Student Performance Analysis**

# %% [markdown]
# ## Objective
# The goal of this project is to analyze student performance data and identify factors affecting final grades (G3).

# %%
import os
print(os.listdir("/content"))
# Out:
# ['.config', 'student_data.csv', 'sample_data']

# %%
print(os.listdir("/content/sample_data"))
# Out:
# ['README.md', 'anscombe.json', 'california_housing_test.csv', 'mnist_test.csv', 'mnist_train_small.csv', 'california_housing_train.csv']

# %%
df = pd.read_csv("student_data.csv")

# %% [markdown]
# ## Data Overview
# We examine the structure and basic information of the dataset.

# %%
df.head()
# Out:
#   school sex  age address famsize Pstatus  Medu  Fedu     Mjob      Fjob  ...  \
# 0     GP   F   18       U     GT3       A     4     4  at_home   teacher  ...
# 1     GP   F   17       U     GT3       T     1     1  at_home     other  ...
# 2     GP   F   15       U     LE3       T     1     1  at_home     other  ...
# 3     GP   F   15       U     GT3       T     4     2   health  services  ...
# 4     GP   F   16       U     GT3       T     3     3    other     other  ...
#
#   famrel freetime  goout  Dalc  Walc health absences  G1  G2  G3
# 0      4        3      4     1     1      3        6   5   6   6
# 1      5        3      3     1     1      3        4   5   5   6
# 2      4        3      2     2     3      3       10   7   8  10
# 3      3        2      2     1     1      5        2  15  14  15
# 4      4        3      2     1     2      5        4   6  10  10
#
# [5 rows x 33 columns]

# %% [markdown]
# ## Data Cleaning
# Checking for missing values and handling them.

# %%
print(df.isnull().sum())

df = df.dropna()
# Out:
# school        0
# sex           0
# age           0
# address       0
# famsize       0
# Pstatus       0
# Medu          0
# Fedu          0
# Mjob          0
# Fjob          0
# reason        0
# guardian      0
# traveltime    0
# studytime     0
# failures      0
# schoolsup     0
# famsup        0
# paid          0
# activities    0
# nursery       0
# higher        0
# internet      0
# romantic      0
# famrel        0
# freetime      0
# goout         0
# Dalc          0
# Walc          0
# health        0
# absences      0
# G1            0
# G2            0
# G3            0
# dtype: int64

# %% [markdown]
# ## Visualization
# Analyzing average grades and distributions.

# %%
print(df.describe())
# Out:
#               age        Medu        Fedu  traveltime   studytime    failures  \
# count  395.000000  395.000000  395.000000  395.000000  395.000000  395.000000
# mean    16.696203    2.749367    2.521519    1.448101    2.035443    0.334177
# std      1.276043    1.094735    1.088201    0.697505    0.839240    0.743651
# min     15.000000    0.000000    0.000000    1.000000    1.000000    0.000000
# 25%     16.000000    2.000000    2.000000    1.000000    1.000000    0.000000
# 50%     17.000000    3.000000    2.000000    1.000000    2.000000    0.000000
# 75%     18.000000    4.000000    3.000000    2.000000    2.000000    0.000000
# max     22.000000    4.000000    4.000000    4.000000    4.000000    3.000000
#
#            famrel    freetime       goout        Dalc        Walc      health  \
# count  395.000000  395.000000  395.000000  395.000000  395.000000  395.000000
# mean     3.944304    3.235443    3.108861    1.481013    2.291139    3.554430
# ...

# %%
import matplotlib.pyplot as plt

df[['G1', 'G2', 'G3']].mean().plot(kind='bar')
plt.title("Average Grades (G1, G2, G3)")
plt.show()

# %% [markdown]
# ### Average Grades Analysis
# The bar chart shows that the average scores for G1, G2, and G3 are relatively close, with a slight decrease in the final grade (G3). This indicates that student performance remains fairly consistent across evaluation periods, though there is a small drop in final outcomes.

# %%
df['G3'].hist()
plt.title("Final Grade Distribution")
plt.xlabel("G3")
plt.ylabel("Frequency")
plt.show()

# %%
df.groupby('studytime')['G3'].mean().plot(kind='bar')
plt.title("Study Time vs Final Grade")
plt.show()

# %% [markdown]
# ## Conclusion
# This project analyzed student performance using various factors such as study time and past grades. The results indicate that consistent academic effort and study habits positively impact final performance, although multiple factors contribute to student success.
